# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D://N Raj//DataSet//data.csv")
df.head()
# Out:
#   Sub-Category     Sales          Region                 Order ID  \
# 0      Copiers   86.2650  Western Europe  ES-2012-KH1663048-40941
# 1      Copiers  106.9725  Western Europe  ES-2014-PS1904545-41845
# 2      Copiers  119.7630  Western Europe  ES-2015-JS1594045-42364
# 3      Copiers  123.8535  Western Europe  IT-2013-AD1018045-41346
# 4      Copiers  123.9300  Western Europe  IT-2015-GM1469548-42173
#
#         Ship Mode Customer ID    Customer Name      Segment      City  \
# 0     First Class  KH-1663048       Ken Heidel    Corporate   Dresden
# 1  Standard Class  PS-1904545  Penelope Sewall  Home Office      Lyon
# 2  Standard Class  JS-1594045  Joni Sundaresam  Home Office  Toulouse
# 3  Standard Class  AD-1018045   Alan Dominguez  Home Office  Chartres
# 4    Second Class  GM-1469548     Greg Maxwell    Corporate   Hanover
#
#                                 State  Country  Market   Product ID  \
# 0                              Saxony  Germany  Europe  TEC-CO-4770
# ...

# %%
df.shape
# Out:
# (268, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sub-Category    268 non-null    object
#  1   Sales           268 non-null    float64
#  2   Region          268 non-null    object
#  3   Order ID        268 non-null    object
#  4   Ship Mode       268 non-null    object
#  5   Customer ID     268 non-null    object
#  6   Customer Name   268 non-null    object
#  7   Segment         268 non-null    object
#  8   City            268 non-null    object
#  9   State           268 non-null    object
#  10  Country         268 non-null    object
#  11  Market          268 non-null    object
#  12  Product ID      268 non-null    object
#  13  Category        268 non-null    object
#  14  Product Name    268 non-null    object
#  15  Order Priority  268 non-null    object
# dtypes: float64(1), object(15)
# memory usage: 33.6+ KB

# %%
df.describe()
# Out:
#              Sales
# count   268.000000
# mean    778.297231
# std     600.778719
# min      86.265000
# 25%     376.453125
# 50%     642.277500
# 75%    1000.110000
# max    4748.436000

# %%
df.describe().sum()
# Out:
# Sales    8500.617575
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Sub-Category      0
# Sales             0
# Region            0
# Order ID          0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Market            0
# Product ID        0
# Category          0
# Product Name      0
# Order Priority    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sample(3)
# Out:
#     Sub-Category    Sales          Region                 Order ID  \
# 264      Copiers  2970.90  Western Europe  ES-2015-TM2101048-42305
# 166      Copiers   757.32  Western Europe  IT-2015-JL1585048-42230
# 190      Copiers   954.54  Western Europe  ES-2015-SE2011048-42335
#
#           Ship Mode Customer ID   Customer Name   Segment       City  \
# 264    Second Class  TM-2101048  Tamara Manning  Consumer      Trier
# 166    Second Class  JL-1585048      John Lucas  Consumer  Stuttgart
# 190  Standard Class  SE-2011048    Sanjit Engle  Consumer  Stuttgart
#
#                     State  Country  Market   Product ID    Category  \
# 264  Rhineland-Palatinate  Germany  Europe  TEC-CO-5997  Technology
# 166     Baden-Württemberg  Germany  Europe  TEC-CO-3710  Technology
# 190     Baden-Württemberg  Germany  Europe  TEC-CO-3596  Technology
#
#                      Product Name Order Priority
# 264      Sharp Fax Machine, Color         Medium
# ...

# %%
sns.boxplot(x="Sub-Category", y="Sales", data=df)  
plt.xticks(rotation=45)   # rotate labels if overlap
plt.show()

# %%
df["Sub-Category"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      Copiers
# 1      Copiers
# 2      Copiers
# 3      Copiers
# 4      Copiers
#         ...
# 263    Copiers
# 264    Copiers
# 265    Copiers
# 266    Copiers
# 267    Copiers
# Name: Sub-Category, Length: 268, dtype: object>

# %%
df["Sub-Category"].value_counts()
# Out:
# Sub-Category
# Copiers    268
# Name: count, dtype: int64

# %%
sns.boxplot(x="Sales",data=df)
# Out:
# <Axes: xlabel='Sales'>

# %%
df["Sales"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        86.2650
# 1       106.9725
# 2       119.7630
# 3       123.8535
# 4       123.9300
#          ...
# 263    2764.3275
# 264    2970.9000
# 265    3421.7100
# 266    3616.5000
# 267    4748.4360
# Name: Sales, Length: 268, dtype: float64>

# %%
df["Sales"].value_counts()
# Out:
# Sales
# 965.0475     3
# 667.5390     3
# 667.9215     3
# 382.1400     2
# 327.9810     2
#             ..
# 512.1630     1
# 513.3600     1
# 520.6800     1
# 523.8600     1
# 4748.4360    1
# Name: count, Length: 247, dtype: int64

# %%
df["Region"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      Western Europe
# 1      Western Europe
# 2      Western Europe
# 3      Western Europe
# 4      Western Europe
#             ...
# 263    Western Europe
# 264    Western Europe
# 265    Western Europe
# 266    Western Europe
# 267    Western Europe
# Name: Region, Length: 268, dtype: object>

# %%
df["Order ID"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       ES-2012-KH1663048-40941
# 1       ES-2014-PS1904545-41845
# 2       ES-2015-JS1594045-42364
# 3       IT-2013-AD1018045-41346
# 4       IT-2015-GM1469548-42173
#                  ...
# 263     ES-2014-SS2041045-41999
# 264     ES-2015-TM2101048-42305
# 265    ES-2014-TH21235125-41814
# 266     ES-2012-DB1306048-41171
# 267     ES-2013-DK1315048-41386
# Name: Order ID, Length: 268, dtype: object>

# %%
print(df.columns.tolist())
# Out:
# ['Sub-Category', 'Sales', 'Region', 'Order ID', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country', 'Market', 'Product ID', 'Category', 'Product Name', 'Order Priority']

# %%
df.columns = df.columns.str.strip()        # remove leading/trailing spaces
df.columns = df.columns.str.replace("\t", " ", regex=True)  # replace tab with space
print(df.columns)
# Out:
# Index(['Sub-Category', 'Sales', 'Region', 'Order ID', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Market', 'Product ID', 'Category', 'Product Name', 'Order Priority'],
#       dtype='object')

# %%
df["Ship Mode Customer"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ship Mode Customer'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df["Ship Mode Customer"].value_counts()
#
# ...

# %%
df["Ship Mode\tCustomer"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ship Mode\tCustomer'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df["Ship Mode\tCustomer"].value_counts()
#
# ...

# %%
df["Ship Mode	Customer"].value_counts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ship Mode\tCustomer'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df["Ship Mode	Customer"].value_counts
#
# ...

# %%
df[""].value_counts

# %%
df[""].value_counts

# %%
df[""].value_counts

# %%
df[""].value_counts

# %%
df["Sales"].unique
# Out:
# <bound method Series.unique of 0        86.2650
# 1       106.9725
# 2       119.7630
# 3       123.8535
# 4       123.9300
#          ...
# 263    2764.3275
# 264    2970.9000
# 265    3421.7100
# 266    3616.5000
# 267    4748.4360
# Name: Sales, Length: 268, dtype: float64>
