# %%
import pandas as pd
import numpy as np

# %%
books=pd.read_csv("D://N Raj//DataSet//Recommender System//Books.csv")
rating=pd.read_csv("D://N Raj//DataSet//Recommender System//Ratings.csv")
users=pd.read_csv("D://N Raj//DataSet//Recommender System//Users.csv")
# Out:
# C:\Users\Solution\AppData\Local\Temp\ipykernel_22560\2094449642.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv("D://N Raj//DataSet//Recommender System//Books.csv")

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
rating.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(users.shape)
print(rating.shape)
# Out:
# (271360, 8)
# (278858, 3)
# (1149780, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
rating.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
rating.duplicated().sum()
# Out:
# 0

# %%
books.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271358               271360
# unique      271360          242135           102022                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/185326119X.0...
# ...

# %%
# user.describe()

# %%
# df=user.info()

# %%
books.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271358               271360
# unique      271360          242135           102022                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/185326119X.0...
# ...

# %%
rating.describe()
# Out:
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
books = pd.DataFrame(books)
books.shape

# %%
df.head(2)

# %% [raw]
# import matplotlib.pyplot as plt
# import seaborn as sns
# books.duplicated().sum()
# books.drop_duplicates(inplace=True)
# sns.boxplot(books['Year-Of-Publication'])

# %% [markdown]
# ## Popularity Based Recommender System

# %% [raw]
# Highest avg rating book show like top 50

# %%
rating_with_name = rating.merge(books,on='ISBN')

# %%
rating_with_name

# %%
rating_with_name.shape
# Out:
# (1031136, 10)

# %% [raw]
# all those books consider which rating is greater than 250

# %%
num_rating_df = rating_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()

# %%
num_rating_df
# Out:
#                                                Book-Title  Book-Rating
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)

# %%
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df = rating_with_name.groupby('Book-Title')['Book-Rating'].mean().reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_ratings'},inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  avg_ratings
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.     0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 241068                                Ã?Â?sterlich leben.     7.000000
# 241069                              Ã?Â?stlich der Berge.     2.666667
# 241070                                  Ã?Â?thique en toc     4.000000
#
# [241071 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
#         avg_ratings
# 0          2.250000
# 1          0.000000
# 2          0.000000
# 3          8.000000
# ...

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_ratings',ascending=False).head(50)
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 80422        Harry Potter and the Goblet of Fire (Book 4)          387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 80426   Harry Potter and the Order of the Phoenix (Boo...          347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)          556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...          281
# 187377  The Fellowship of the Ring (The Lord of the Ri...          368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 211384     The Two Towers (The Lord of the Rings, Part 2)          260
# 219741                              To Kill a Mockingbird          510
# 183573                                  The Da Vinci Code          898
# 187880                 The Five People You Meet in Heaven          430
# ...

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
popular_df.merge(books, on='Book-Title').drop_duplicates('Book-Title')
# Out:
#                                             Book-Title  num_ratings  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 3         Harry Potter and the Goblet of Fire (Book 4)          387
# 5       Harry Potter and the Sorcerer's Stone (Book 1)          278
# 9    Harry Potter and the Order of the Phoenix (Boo...          347
# 13    Harry Potter and the Chamber of Secrets (Book 2)          556
# 16   The Hobbit : The Enchanting Prelude to The Lor...          281
# 17   The Fellowship of the Ring (The Lord of the Ri...          368
# 26   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 28      The Two Towers (The Lord of the Rings, Part 2)          260
# 39                               To Kill a Mockingbird          510
# 47                                   The Da Vinci Code          898
# 53                  The Five People You Meet in Heaven          430
# 55                              The Catcher in the Rye          449
# ...

# %%
popular_df.merge(books, on='Book-Title').drop_duplicates('Book-Title').shape
# Out:
# (50, 10)

# %%
print(books.columns)
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
popular_df = popular_df.merge(books, on='Book-Title').drop_duplicates('Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_ratings']]
popular_df
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 39                               To Kill a Mockingbird
# 47                                   The Da Vinci Code
# 53                  The Five People You Meet in Heaven
# 55                              The Catcher in the Rye
# 62                           The Lovely Bones: A Novel
# 63                                                1984
# 72                            Prodigal Summer: A Novel
# ...

# %%
print(books.columns)
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
popular_df["Image-URL-M"][0]
# Out:
# 'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'

# %% [markdown]
# ## Collaobrative Filtering Based Recommender System

# %%
rating_with_name.sample(3)
# Out:
#         User-ID        ISBN  Book-Rating  \
# 223681   128208  0385335881            0
# 360055    19605  038549744X            0
# 560095    69697  0821759973            0
#
#                                                Book-Title        Book-Author  \
# 223681  Shopaholic Takes Manhattan (Summer Display Opp...    Sophie Kinsella
# 360055                                 English Passengers     Matthew Kneale
# 560095                                      In Our Dreams  Linda Lael Miller
#
#        Year-Of-Publication               Publisher  \
# 223681                2002                   Delta
# 360055                2001  Anchor Books/Doubleday
# 560095                1998             Zebra Books
#
#                                               Image-URL-S  \
# 223681  http://images.amazon.com/images/P/0385335881.0...
# 360055  http://images.amazon.com/images/P/038549744X.0...
# 560095  http://images.amazon.com/images/P/0821759973.0...
#
# ...

# %%
x=rating_with_name.groupby('User-ID').count()["Book-Rating"]>200
padhe_likhe_users = x[x].index

# %%
filtered_rating = rating_with_name[rating_with_name['User-ID'].isin(padhe_likhe_users)]
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
famous_books
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=706)

# %%
final_ratings.drop_duplicates()
# Out:
#          User-ID        ISBN  Book-Rating              Book-Title  \
# 63        278418  0446520802            0            The Notebook
# 65          3363  0446520802            0            The Notebook
# 66          7158  0446520802           10            The Notebook
# 69         11676  0446520802           10            The Notebook
# 74         23768  0446520802            6            The Notebook
# ...          ...         ...          ...                     ...
# 1026724   266865  0531001725           10  The Catcher in the Rye
# 1027923   269566  0670809381            0                  Echoes
# 1028777   271284  0440910927            0           The Rainmaker
# 1029070   271705  B0001PIOX4            0          Fahrenheit 451
# 1030868   275970  1586210661            9  Me Talk Pretty One Day
#
#                    Book-Author Year-Of-Publication                Publisher  \
# 63             Nicholas Sparks                1996             Warner Books
# ...

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
pt = final_ratings.pivot_table(index="Book-Title",columns="User-ID",values="Book-Rating")

# %%
pt.fillna(0, inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity_score = cosine_similarity(pt).shape # 706 book ka 706 book ka sath nuclier distance

# %%
similarity_score
# Out:
# (706, 706)

# %%
 def recommend(book_name):
     # index fetch
     index = np.where(pt.index=="Zoya")[0][0]
     similar_items= sorted(list(enumerate(similarity_score[0])),key= lambda x:x[1],reverse=True)
     return suggestions

# %%
type(similarity_score)
print(similarity_score)
# Out:
# [[1.         0.10255025 0.01220856 ... 0.12110367 0.07347567 0.04316046]
#  [0.10255025 1.         0.2364573  ... 0.07446129 0.16773875 0.14263397]
#  [0.01220856 0.2364573  1.         ... 0.04558758 0.04938579 0.10796119]
#  ...
#  [0.12110367 0.07446129 0.04558758 ... 1.         0.07085128 0.0196177 ]
#  [0.07347567 0.16773875 0.04938579 ... 0.07085128 1.         0.10602962]
#  [0.04316046 0.14263397 0.10796119 ... 0.0196177  0.10602962 1.        ]]

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_score = cosine_similarity(pt)   # pt = pivot table or matrix

# %%
similarity_score.shape   # should show (num_books, num_books)
# Out:
# (706, 706)

# %%
 def recommend(book_name):
     # index fetch
     index = np.where(pt.index=="book_name")[0][0]
     similar_items= sorted(list(enumerate(similarity_score[index])),key= lambda x:x[1],reverse=True)[1:6]
     
     for i in similar_items:
         print(pt.index[i[0]])

# %%
recommend('1984')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 recommend('1984')
#
# Cell In[72], line 3, in recommend(book_name)
#       1 def recommend(book_name):
#       2     # index fetch
# ----> 3     index = np.where(pt.index=="book_name")[0][0]
#       4     similar_items= sorted(list(enumerate(similarity_score[index])),key= lambda x:x[1],reverse=True)[1:6]
#       6     for i in similar_items:
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
pt.index[47]
# Out:
# 'Animal Farm'

# %% [raw]
# def recommend(book_name):
#     if book_name not in pt.index:
#         print("❌ Book not found in dataset. Please check spelling or try another book.")
#         return
#
#     index = np.where(pt.index == book_name)[0][0]
#     similar_items = sorted(list(enumerate(similarity_score[index])),
#                            key=lambda x: x[1],
#                            reverse=True)[1:10]
#
#     print(f"📚 Books similar to '{book_name}':\n")
#     for i in similar_items:
#         print(pt.index[i[0]])

# %%
def recommend(book_name):
    if book_name not in pt.index:
        print("❌ Book not found in dataset. Please check spelling or try another book.")
        return

    index = np.where(pt.index == book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_score[index])),
                           key=lambda x: x[1],
                           reverse=True)[1:10]
    data = []
    print(f"📚 Books similar to '{book_name}':\n")
    for i in similar_items:
        item = []
        # print(pt.index[i[0]])
        # print(books[books['Book-Title'] == pt.index[i[0]]])
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))

        data.append(item)

    return data

# %%
recommend('Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
# 📚 Books similar to 'Harry Potter and the Chamber of Secrets (Book 2)':
# [['Harry Potter and the Prisoner of Azkaban (Book 3)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'],
#  ['Harry Potter and the Goblet of Fire (Book 4)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439139597.01.MZZZZZZZ.jpg'],
#  ["Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/059035342X.01.MZZZZZZZ.jpg'],
#  ["Harry Potter and the Sorcerer's Stone (Book 1)",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0590353403.01.MZZZZZZZ.jpg'],
#  ['Harry Potter and the Order of the Phoenix (Book 5)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/043935806X.01.MZZZZZZZ.jpg'],
#  ["Charlotte's Web (Trophy Newbery)",
#   'E. B. White',
#   'http://images.amazon.com/images/P/0064400557.01.MZZZZZZZ.jpg'],
# ...

# %%
recommend('Message in a Bottle')
# Out:
# 📚 Books similar to 'Message in a Bottle':
# [[776    Nights in Rodanthe
#   Name: Book-Title, dtype: object,
#   776    Nicholas Sparks
#   Name: Book-Author, dtype: object,
#   776    http://images.amazon.com/images/P/0446531332.0...
#   Name: Image-URL-M, dtype: object],
#  [4448    The Mulberry Tree
#   Name: Book-Title, dtype: object,
#   4448    Jude Deveraux
#   Name: Book-Author, dtype: object,
#   4448    http://images.amazon.com/images/P/0743437640.0...
#   Name: Image-URL-M, dtype: object],
#  [5607    A Walk to Remember
#   Name: Book-Title, dtype: object,
#   5607    Nicholas Sparks
#   Name: Book-Author, dtype: object,
#   5607    http://images.amazon.com/images/P/0446608955.0...
#   Name: Image-URL-M, dtype: object],
#  [584    River's End
#   Name: Book-Title, dtype: object,
#   584    Nora Roberts
#   Name: Book-Author, dtype: object,
#   584    http://images.amazon.com/images/P/0515127833.0...
#   Name: Image-URL-M, dtype: object],
# ...

# %%
recommend('1984')
# Out:
# 📚 Books similar to '1984':
# [[['Animal Farm'],
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  [["The Handmaid's Tale"],
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  [['Brave New World'],
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  [['The Vampire Lestat (Vampire Chronicles, Book II)'],
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg'],
#  [['The Hours : A Novel'],
#   'Michael Cunningham',
#   'http://images.amazon.com/images/P/0312243022.01.MZZZZZZZ.jpg'],
#  [['Fahrenheit 451'],
#   'Ray Bradbury',
#   'http://images.amazon.com/images/P/3257208626.01.MZZZZZZZ.jpg'],
#  [['The Catcher in the Rye'],
#   'J.D. Salinger',
#   'http://images.amazon.com/images/P/0316769487.01.MZZZZZZZ.jpg'],
#  [['Naked'],
#   'David Sedaris',
#   'http://images.amazon.com/images/P/0316777730.01.MZZZZZZZ.jpg'],
# ...

# %%
recommend('The Notebook')
# Out:
# 📚 Books similar to 'The Notebook':
#
# A Walk to Remember
# The Rescue
# One Door Away from Heaven
# Toxin
# The Five People You Meet in Heaven
# Nights in Rodanthe
# Suzanne's Diary for Nicholas
# Everything's Eventual : 14 Dark Tales
# The Guardian

# %% [raw]
# Same auther famous book recommended

# %%
recommend('The Da Vinci Code')

# %%
recommend('The Hobbit : The Enchanting Prelude to The Lord of the Rings')

# %%
image=list(popular_df['Image-URL-M'].values)

# %%
import pickle
pickle.dump(popular_df,open("popular.pkl","wb"))

# %%
import pickle
popular_df = pickle.load(open('popular.pkl', 'rb'))
print(popular_df.columns)
# Out:
# Index(['Book-Title', 'Book-Author', 'Image-URL-M', 'num_ratings',
#        'avg_ratings'],
#       dtype='object')

# %%
import pickle
pickle.dump(pt, open('pt.pkl', 'wb'))
pickle.dump(books, open('books.pkl', 'wb'))
pickle.dump(similarity_score, open('similarity_scores.pkl', 'wb'))

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
print("numpy",np.__version__)
print("pandas",np.__version__)
print("sklearn",np.__version__)
# Out:
# numpy 1.26.4
# pandas 1.26.4
# sklearn 1.26.4
